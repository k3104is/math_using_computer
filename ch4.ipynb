# %%
print("hello")
# Out:
# hello

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import sympy as sym
from collections import Counter
from patsy import dmatrices
from scipy import linalg, stats
from scipy.integrate import quad
from scipy.optimize import minimize
from sklearn.linear_model import LinearRegression
from statsmodels.stats.proportion import binom_test
from statsmodels.stats.weightstats import CompareMeans, DescrStatsW, ttest_ind
from sympy import *
from sympy. stats import *
from sympy.plotting import plot3d

# %%
#4.1
var('x')
plot(x**2 + 2*x - 4, (x, -5, 3))

# %%
#4.2
x = np.linspace(-5, 3, 101)
y = x**2 + 2*x -4
plt.plot(x,y)

# %%
x
# Out:
# array([-5.  , -4.92, -4.84, -4.76, -4.68, -4.6 , -4.52, -4.44, -4.36,
#        -4.28, -4.2 , -4.12, -4.04, -3.96, -3.88, -3.8 , -3.72, -3.64,
#        -3.56, -3.48, -3.4 , -3.32, -3.24, -3.16, -3.08, -3.  , -2.92,
#        -2.84, -2.76, -2.68, -2.6 , -2.52, -2.44, -2.36, -2.28, -2.2 ,
#        -2.12, -2.04, -1.96, -1.88, -1.8 , -1.72, -1.64, -1.56, -1.48,
#        -1.4 , -1.32, -1.24, -1.16, -1.08, -1.  , -0.92, -0.84, -0.76,
#        -0.68, -0.6 , -0.52, -0.44, -0.36, -0.28, -0.2 , -0.12, -0.04,
#         0.04,  0.12,  0.2 ,  0.28,  0.36,  0.44,  0.52,  0.6 ,  0.68,
#         0.76,  0.84,  0.92,  1.  ,  1.08,  1.16,  1.24,  1.32,  1.4 ,
#         1.48,  1.56,  1.64,  1.72,  1.8 ,  1.88,  1.96,  2.04,  2.12,
#         2.2 ,  2.28,  2.36,  2.44,  2.52,  2.6 ,  2.68,  2.76,  2.84,
#         2.92,  3.  ])

# %%
#4.4
var('x y')
plot3d(x**2 + y**2, (x, -1, 1), (y, -1, 1))

# %%
#4.5
plotting.plot_contour(x**2 + y**2, (x, -1, 1), (y, -1, 1))

# %%
#4.6
plot_implicit(Eq(x**2 + y**2, 1))

# %%
#4.7
plot_implicit(x**2 + y**2 <= 1)

# %%
#4.8
plot_implicit(Or(Eq(2*x+3*y, 8), Eq(5*x-7*y, -9)))

# %%
#4.9
plot_implicit(And(y <= x, y >= x**2), (x, 0, 2), (y, 0, 2))

# %%
#4.11
var('x')
a, b = sorted(solve(Eq(x, x**2), x))
integrate(x - x**2, (x, a, b))
# Out:
# 1/6

# %%
#4.13
var('x')
solve(Eq(x**2 + 2*x - 4, 0), x)
# Out:
# [-1 + sqrt(5), -sqrt(5) - 1]

# %%
#4.14
var('x')
a, b = solve(Eq(x**2 + 2*x - 4, 0), x)
a + b
# Out:
# -2

# %%
var('x')
n = 3; simplify(sum(solve(x**n + 2*x - 4, x)))
# Out:
# 0

# %%
plot_implicit(Eq(x**n + 2*x - 4, y))

# %%
#4.15
var('x y')
sol = solve([Eq(2*x + 3*y, 8), Eq(5*x - 7*y, -9)], [x, y]); sol
# Out:
# {x: 1, y: 2}

# %%
#4.16
x1, y1 = sol.values()
x1 + y1
# Out:
# 3

# %%
#4.17
var('x')
solve(Eq(2**x + sin(x), 0), x)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[38], line 3
#       1 #4.17
#       2 var('x')
# ----> 3 solve(Eq(2**x + sin(x), 0), x)
#
# File /opt/conda/lib/python3.11/site-packages/sympy/solvers/solvers.py:1145, in solve(f, *symbols, **flags)
#    1143         solution = _solve_undetermined(f[0], symbols, flags)
#    1144     if not solution:
# -> 1145         solution = _solve(f[0], *symbols, **flags)
#    1146 else:
#    1147     linear, solution = _solve_system(f, symbols, **flags)
#
# File /opt/conda/lib/python3.11/site-packages/sympy/solvers/solvers.py:1693, in _solve(f, *symbols, **flags)
#    1690 # ----------- end of fallback ----------------------------
#    1692 if result is False:
# -> 1693     raise NotImplementedError('\n'.join([msg, not_impl_msg % f]))
#    1695 result = _remove_duplicate_solutions(result)
#    1697 if flags.get('simplify', True):
#
# NotImplementedError: multiple generators [2**x, sin(x)]
# No algorithms are implemented to solve equation 2**x + sin(x)

# %%
#4.17
var('x')
f = 2**x + sin(x)
nsolve(f, x, 0)
# Out:
# -0.676181670362621

# %%
plot_implicit(Eq(f - y, 0), (x, -8, 4), (y, -2, 8))

# %%
#4.18
var('x')
solve(x**2 + 2*x - 4 < 0, x)
# Out:
# (x < -1 + sqrt(5)) & (-sqrt(5) - 1 < x)
